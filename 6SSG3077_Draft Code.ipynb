# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# Load the cleaned GeoJSON data
geojson_file_path = r"/Users/chenyutong/Downloads/updated_geojson.geojson"
data = gpd.read_file(geojson_file_path)

# Define the resilient communities (resilient)
resilient = data[
    (data['HDX_2018-2022'] > data['HDX_2018-2022'].median()) &
    (data['VRDIDR_2018-2022'] < data['VRDIDR_2018-2022'].median()) &
    (data['EDE_2018-2022'] < data['EDE_2018-2022'].median())
]
resilient = resilient.sort_values(by=['HDX_2018-2022'], ascending=False).head(7)

# Define the culturally protected communities (cultural_protection)
cultural_protection = data[
    (data['NCZ_2018-2022'] > data['NCZ_2018-2022'].median()) &
    (data['LEQ_2018-2022'] > data['LEQ_2018-2022'].median())
]
cultural_protection = cultural_protection.sort_values(by=['NCZ_2018-2022'], ascending=False).head(7)

# Define the wealth paradox communities (wealth_paradox)
wealth_paradox = data[
    (data['INC_2018-2022'] > data['INC_2018-2022'].quantile(0.75)) &
    (data['VRDIDR_2018-2022'] > data['VRDIDR_2018-2022'].median())
]
wealth_paradox = wealth_paradox.sort_values(by=['VRDIDR_2018-2022'], ascending=False).head(7)

# Plot the resilient communities
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
base = data.plot(ax=ax, color='lightgrey', edgecolor='black')
resilient.plot(ax=base, color='darkgreen', legend=True)
plt.title('Resilient Communities (Strongest 7)', fontsize=16)
plt.savefig('resilient_communities_map.png')
plt.show()

# Plot the culturally protected communities
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
base = data.plot(ax=ax, color='lightgrey', edgecolor='black')
cultural_protection.plot(ax=base, color='darkblue', legend=True)
plt.title('Culturally Protected Communities (Strongest 7)', fontsize=16)
plt.savefig('cultural_protection_map.png')
plt.show()

# Plot the wealth paradox communities
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
base = data.plot(ax=ax, color='lightgrey', edgecolor='black')
wealth_paradox.plot(ax=base, color='darkred', legend=True)
plt.title('Wealth Paradox Communities (Top 7)', fontsize=16)
plt.savefig('wealth_paradox_map.png')
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import colors
import numpy as np

# Load the cleaned GeoJSON data
geojson_file_path = r"/Users/chenyutong/Downloads/updated_geojson.geojson"
data = gpd.read_file(geojson_file_path)

# Define colormap settings for gradual representation
cmap_green = plt.cm.Greens
cmap_blue = plt.cm.Blues
cmap_red = plt.cm.Reds

# Plot Chicago overall with gradients
fig, ax = plt.subplots(1, 3, figsize=(24, 8))

# Resilient communities map (gradual green)
data.plot(column='HDX_2018-2022', cmap=cmap_green, linewidth=0.8, ax=ax[0], edgecolor='0.8', legend=False)
ax[0].set_title('Resilient Communities', fontsize=16)
ax[0].axis('off')

# Culturally protected communities map (gradual blue)
data.plot(column='NCZ_2018-2022', cmap=cmap_blue, linewidth=0.8, ax=ax[1], edgecolor='0.8', legend=False)
ax[1].set_title('Culturally Protected Communities', fontsize=16)
ax[1].axis('off')

# Wealth paradox communities map (gradual red)
data.plot(column='INC_2018-2022', cmap=cmap_red, linewidth=0.8, ax=ax[2], edgecolor='0.8', legend=False)
ax[2].set_title('Wealth Paradox Communities', fontsize=16)
ax[2].axis('off')

plt.tight_layout()
plt.savefig('overall_chicago_community_gradual_maps.png')
plt.show()

# Define the resilient communities (resilient)
resilient = data[
    (data['HDX_2018-2022'] > data['HDX_2018-2022'].median()) &
    (data['VRDIDR_2018-2022'] < data['VRDIDR_2018-2022'].median()) &
    (data['EDE_2018-2022'] < data['EDE_2018-2022'].median())
]
resilient = resilient.sort_values(by=['HDX_2018-2022'], ascending=False).head(7)

# Define the culturally protected communities (cultural_protection)
cultural_protection = data[
    (data['NCZ_2018-2022'] > data['NCZ_2018-2022'].median()) &
    (data['LEQ_2018-2022'] > data['LEQ_2018-2022'].median())
]
cultural_protection = cultural_protection.sort_values(by=['NCZ_2018-2022'], ascending=False).head(7)

# Define the wealth paradox communities (wealth_paradox)
wealth_paradox = data[
    (data['INC_2018-2022'] > data['INC_2018-2022'].quantile(0.75)) &
    (data['VRDIDR_2018-2022'] > data['VRDIDR_2018-2022'].median())
]
wealth_paradox = wealth_paradox.sort_values(by=['VRDIDR_2018-2022'], ascending=False).head(7)

# Plot the resilient communities with labels
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
base = data.plot(ax=ax, color='lightgrey', edgecolor='black')
resilient.plot(ax=base, color='darkgreen', legend=True)

# Add annotation for each top 7 resilient community
for x, y, label in zip(resilient.geometry.centroid.x, resilient.geometry.centroid.y, resilient['Name']):
    ax.annotate(label, xy=(x, y), xytext=(-150, 0), textcoords='offset points',
                arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, bbox=dict(facecolor='white', alpha=0.6))

plt.title('Resilient Communities (Strongest 7)', fontsize=16)
plt.savefig('resilient_communities_map_with_labels.png')
plt.show()

# Plot the culturally protected communities with labels
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
base = data.plot(ax=ax, color='lightgrey', edgecolor='black')
cultural_protection.plot(ax=base, color='darkblue', legend=True)

# Add annotation for each top 7 culturally protected community
for x, y, label in zip(cultural_protection.geometry.centroid.x, cultural_protection.geometry.centroid.y, cultural_protection['Name']):
    ax.annotate(label, xy=(x, y), xytext=(-150, 0), textcoords='offset points',
                arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, bbox=dict(facecolor='white', alpha=0.6))

plt.title('Culturally Protected Communities (Strongest 7)', fontsize=16)
plt.savefig('cultural_protection_map_with_labels.png')
plt.show()

# Plot the wealth paradox communities with labels
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
base = data.plot(ax=ax, color='lightgrey', edgecolor='black')
wealth_paradox.plot(ax=base, color='darkred', legend=True)

# Add annotation for each top 7 wealth paradox community
for x, y, label in zip(wealth_paradox.geometry.centroid.x, wealth_paradox.geometry.centroid.y, wealth_paradox['Name']):
    ax.annotate(label, xy=(x, y), xytext=(-150, 0), textcoords='offset points',
                arrowprops=dict(arrowstyle='->', color='black'), fontsize=10, bbox=dict(facecolor='white', alpha=0.6))

plt.title('Wealth Paradox Communities (Top 7)', fontsize=16)
plt.savefig('wealth_paradox_map_with_labels.png')
plt.show()
# Out:
# /var/folders/0f/x5ld7bsd51bf2l_h0h0sl0hw0000gn/T/ipykernel_87193/582612289.py:66: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   for x, y, label in zip(resilient.geometry.centroid.x, resilient.geometry.centroid.y, resilient['Name']):
# /var/folders/0f/x5ld7bsd51bf2l_h0h0sl0hw0000gn/T/ipykernel_87193/582612289.py:80: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   for x, y, label in zip(cultural_protection.geometry.centroid.x, cultural_protection.geometry.centroid.y, cultural_protection['Name']):
# ...

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN, KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score

# Load the cleaned GeoJSON data
gdf = gpd.read_file(r"/Users/chenyutong/Downloads/updated_geojson.geojson")

# Step 1: Standardizing the Data
# Select independent variables for clustering
independent_vars = ['HDX_2018-2022', 'INC_2018-2022', 'HTJ_2018-2022', 
                    'NCZ_2018-2022', 'LEQ_2018-2022', 'EDB_2018-2022', 
                    'EDE_2018-2022', 'UNS_2018-2022', 'MCD_2018-2022']

# Extract and standardize the independent variables
data = gdf[independent_vars]
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Step 2: Clustering Analysis
# DBSCAN Clustering
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan_labels = dbscan.fit_predict(data_scaled)
gdf['DBSCAN_Cluster'] = dbscan_labels

# KMeans Clustering
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans_labels = kmeans.fit_predict(data_scaled)
gdf['KMeans_Cluster'] = kmeans_labels

# Agglomerative Clustering
agglo = AgglomerativeClustering(n_clusters=5)
agglo_labels = agglo.fit_predict(data_scaled)
gdf['Agglomerative_Cluster'] = agglo_labels

# Silhouette Score Evaluation
kmeans_silhouette = silhouette_score(data_scaled, kmeans_labels)
print(f"Silhouette Score for KMeans: {kmeans_silhouette}")

agglo_silhouette = silhouette_score(data_scaled, agglo_labels)
print(f"Silhouette Score for Agglomerative Clustering: {agglo_silhouette}")

# Step 3: Visualization
# Plot DBSCAN Clustering Result with a more gradual color scheme
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf[gdf['DBSCAN_Cluster'] != -1].plot(column='DBSCAN_Cluster', ax=base, cmap='viridis', legend=True, alpha=0.8,aspect=1)
plt.title('DBSCAN Clustering of Chicago Communities')
plt.axis('off')
plt.savefig('dbscan_clustering_map.png')
plt.show()

# Plot KMeans Clustering Result with a more gradual color scheme
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf.plot(column='KMeans_Cluster', ax=base, cmap='Blues', legend=True, alpha=0.8,aspect=1)
plt.title('KMeans Clustering of Chicago Communities')
plt.axis('off')
plt.savefig('kmeans_clustering_map.png')
plt.show()

# Plot Agglomerative Clustering Result with a more gradual color scheme
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf.plot(column='Agglomerative_Cluster', ax=base, cmap='Reds', legend=True, alpha=0.8,aspect=1)
plt.title('Agglomerative Clustering of Chicago Communities')
plt.axis('off')
plt.savefig('agglomerative_clustering_map.png')
plt.show()
# Out:
# Silhouette Score for KMeans: 0.33379877448575124
# Silhouette Score for Agglomerative Clustering: 0.31807359454082706
# /Users/chenyutong/anaconda3/envs/sds2024/lib/python3.12/site-packages/geopandas/plotting.py:695: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(

# %%
import folium

# Create a map centered at an average location from the dataset
average_lat = sum(
    feature["properties"]["Latitude"] for feature in geojson_data["features"]
) / len(geojson_data["features"])
average_lon = sum(
    feature["properties"]["Longitude"] for feature in geojson_data["features"]
) / len(geojson_data["features"])
map_center = [average_lat, average_lon]

# Initialize the map
m = folium.Map(location=map_center, zoom_start=11)

# Add the GeoJSON data to the map
folium.GeoJson(
    geojson_data,
    name="Community Areas",
    tooltip=folium.GeoJsonTooltip(fields=["Name", "Population"], aliases=["Name", "Population"]),
).add_to(m)



map_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       1 import folium
#       3 # Create a map centered at an average location from the dataset
#       4 average_lat = sum(
# ----> 5     feature["properties"]["Latitude"] for feature in geojson_data["features"]
#       6 ) / len(geojson_data["features"])
#       7 average_lon = sum(
#       8     feature["properties"]["Longitude"] for feature in geojson_data["features"]
#       9 ) / len(geojson_data["features"])
#      10 map_center = [average_lat, average_lon]
#
# NameError: name 'geojson_data' is not defined

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score

# Load the cleaned GeoJSON data
gdf = gpd.read_file(r"/Users/chenyutong/Downloads/updated_geojson.geojson")

# Step 1: Standardizing the Data
# Select independent variables for clustering
independent_vars = ['HDX_2018-2022', 'INC_2018-2022', 'HTJ_2018-2022', 
                    'NCZ_2018-2022', 'LEQ_2018-2022', 'EDB_2018-2022', 
                    'EDE_2018-2022', 'UNS_2018-2022', 'MCD_2018-2022']

# Extract and standardize the independent variables
data = gdf[independent_vars]
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Step 2: Finding Optimal K for KMeans using Elbow Method (Manual)
inertia = []
silhouette_scores = []
k_values = range(2, 15)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data_scaled)
    inertia.append(kmeans.inertia_)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(data_scaled, labels))

# Plot the Elbow Method
plt.figure(figsize=(10, 6))
plt.plot(k_values, inertia, 'bo-', markersize=8)
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.savefig('elbow_method_manual.png')
plt.show()

# Plot Silhouette Scores for Different K Values
plt.figure(figsize=(10, 6))
plt.plot(k_values, silhouette_scores, 'go-', markersize=8)
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Different k Values')
plt.savefig('silhouette_scores_manual.png')
plt.show()

# Step 3: KMeans Clustering with Optimal K (Assuming k=5 based on elbow and silhouette scores)
optimal_k = 5  # You may adjust this value based on the elbow plot and silhouette scores
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans_labels = kmeans.fit_predict(data_scaled)
gdf['KMeans_Cluster'] = kmeans_labels

# Step 4: Silhouette Score for KMeans
kmeans_silhouette = silhouette_score(data_scaled, kmeans_labels)
print(f"Silhouette Score for KMeans with k={optimal_k}: {kmeans_silhouette}")

# Step 5: DBSCAN Clustering Parameter Tuning
# Testing different values for eps
best_eps = 0.1
best_silhouette = -1
for eps in np.arange(0.1, 2.0, 0.1):
    dbscan = DBSCAN(eps=eps, min_samples=5)
    labels = dbscan.fit_predict(data_scaled)
    # Ignore if only one cluster or all noise
    if len(set(labels)) > 1 and -1 not in labels:
        score = silhouette_score(data_scaled, labels)
        if score > best_silhouette:
            best_silhouette = score
            best_eps = eps

print(f"Optimal eps for DBSCAN: {best_eps}, Silhouette Score: {best_silhouette}")

# Step 6: DBSCAN with Optimal Parameters
dbscan = DBSCAN(eps=best_eps, min_samples=5)
dbscan_labels = dbscan.fit_predict(data_scaled)
gdf['DBSCAN_Cluster'] = dbscan_labels

# Step 7: Agglomerative Clustering
# Trying with the same number of clusters as the optimal K from KMeans
agglo = AgglomerativeClustering(n_clusters=optimal_k)
agglo_labels = agglo.fit_predict(data_scaled)
gdf['Agglomerative_Cluster'] = agglo_labels

# Step 8: Silhouette Score Evaluation
agglo_silhouette = silhouette_score(data_scaled, agglo_labels)
print(f"Silhouette Score for Agglomerative Clustering with k={optimal_k}: {agglo_silhouette}")

# Step 9: Visualization with Adjusted Parameters
# Plot KMeans Clustering Result with Optimal K
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf.plot(column='KMeans_Cluster', ax=base, cmap='Blues', legend=True, alpha=0.8,aspect=1)
plt.title(f'KMeans Clustering of Chicago Communities (k={optimal_k})')
plt.axis('off')
plt.savefig('kmeans_clustering_optimized.png')
plt.show()

# Plot DBSCAN Clustering Result with Optimal eps
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf[gdf['DBSCAN_Cluster'] != -1].plot(column='DBSCAN_Cluster', ax=base, cmap='viridis', legend=True, alpha=0.8,aspect=1)
plt.title(f'DBSCAN Clustering of Chicago Communities (eps={best_eps})')
plt.axis('off')
plt.savefig('dbscan_clustering_optimized.png')
plt.show()

# Plot Agglomerative Clustering Result with Optimal K
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf.plot(column='Agglomerative_Cluster', ax=base, cmap='Reds', legend=True, alpha=0.8,aspect=1)
plt.title(f'Agglomerative Clustering of Chicago Communities (k={optimal_k})')
plt.axis('off')
plt.savefig('agglomerative_clustering_optimized.png')
plt.show()
# Out:
# Silhouette Score for KMeans with k=5: 0.33379877448575124
# Optimal eps for DBSCAN: 0.1, Silhouette Score: -1
# Silhouette Score for Agglomerative Clustering with k=5: 0.31807359454082706
# /Users/chenyutong/anaconda3/envs/sds2024/lib/python3.12/site-packages/geopandas/plotting.py:695: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score

# Load the cleaned GeoJSON data
gdf = gpd.read_file(r"/Users/chenyutong/Downloads/updated_geojson.geojson")

# Step 1: Standardizing the Data
# Select independent variables for clustering
independent_vars = ['HDX_2018-2022', 'INC_2018-2022', 'HTJ_2018-2022', 
                    'NCZ_2018-2022', 'LEQ_2018-2022', 'EDB_2018-2022', 
                    'EDE_2018-2022', 'UNS_2018-2022', 'MCD_2018-2022']

# Extract and standardize the independent variables
data = gdf[independent_vars]
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Step 2: Apply PCA for Dimensionality Reduction
# Reduce dimensions to 2 for visualization and improving clustering performance
pca = PCA(n_components=2)
data_pca = pca.fit_transform(data_scaled)

# Step 3: KMeans Clustering with PCA Data
# Finding optimal K using silhouette scores
k_values = range(2, 15)
silhouette_scores = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(data_pca)
    silhouette_scores.append(silhouette_score(data_pca, labels))

# Plot Silhouette Scores for Different K Values
plt.figure(figsize=(10, 6))
plt.plot(k_values, silhouette_scores, 'go-', markersize=8)
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Different k Values (PCA Data)')
plt.savefig('silhouette_scores_pca.png')
plt.show()

# Step 4: KMeans Clustering with Optimal K (Assuming k=4 based on silhouette scores)
optimal_k = 4  # Adjust based on silhouette scores plot
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans_labels = kmeans.fit_predict(data_pca)
gdf['KMeans_Cluster_PCA'] = kmeans_labels

# Step 5: Silhouette Score for KMeans with PCA Data
kmeans_silhouette = silhouette_score(data_pca, kmeans_labels)
print(f"Silhouette Score for KMeans with PCA and k={optimal_k}: {kmeans_silhouette}")

# Step 6: DBSCAN Clustering with PCA Data
# Testing different values for eps
best_eps = 0.1
best_silhouette = -1
for eps in np.arange(0.1, 2.0, 0.1):
    dbscan = DBSCAN(eps=eps, min_samples=5)
    labels = dbscan.fit_predict(data_pca)
    # Ignore if only one cluster or all noise
    if len(set(labels)) > 1 and -1 not in labels:
        score = silhouette_score(data_pca, labels)
        if score > best_silhouette:
            best_silhouette = score
            best_eps = eps

print(f"Optimal eps for DBSCAN (PCA Data): {best_eps}, Silhouette Score: {best_silhouette}")

# Apply DBSCAN with Optimal eps
dbscan = DBSCAN(eps=best_eps, min_samples=5)
dbscan_labels = dbscan.fit_predict(data_pca)
gdf['DBSCAN_Cluster_PCA'] = dbscan_labels

# Step 7: Agglomerative Clustering with PCA Data
# Trying with the same number of clusters as the optimal K from KMeans
agglo = AgglomerativeClustering(n_clusters=optimal_k)
agglo_labels = agglo.fit_predict(data_pca)
gdf['Agglomerative_Cluster_PCA'] = agglo_labels

# Step 8: Silhouette Score Evaluation for Agglomerative Clustering
agglo_silhouette = silhouette_score(data_pca, agglo_labels)
print(f"Silhouette Score for Agglomerative Clustering with PCA and k={optimal_k}: {agglo_silhouette}")

# Step 9: Visualization with PCA Data
# Plot KMeans Clustering Result with PCA Data
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf.plot(column='KMeans_Cluster_PCA', ax=base, cmap='Blues', legend=True, alpha=0.8)
plt.title(f'KMeans Clustering of Chicago Communities (PCA, k={optimal_k})')
plt.axis('off')
plt.savefig('1kmeans_clustering_pca.png')
plt.show()

# Plot DBSCAN Clustering Result with PCA Data
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf[gdf['DBSCAN_Cluster_PCA'] != -1].plot(column='DBSCAN_Cluster_PCA', ax=base, cmap='viridis', legend=True, alpha=0.8)
plt.title(f'DBSCAN Clustering of Chicago Communities (PCA, eps={best_eps})')
plt.axis('off')
plt.savefig('1dbscan_clustering_pca.png')
plt.show()

# Plot Agglomerative Clustering Result with PCA Data
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf.plot(column='Agglomerative_Cluster_PCA', ax=base, cmap='Reds', legend=True, alpha=0.8)
plt.title(f'Agglomerative Clustering of Chicago Communities (PCA, k={optimal_k})')
plt.axis('off')
plt.savefig('1agglomerative_clustering_pca.png')
plt.show()
# Out:
# Silhouette Score for KMeans with PCA and k=4: 0.5204059836939079
# Optimal eps for DBSCAN (PCA Data): 1.1, Silhouette Score: 0.4025599132644327
# Silhouette Score for Agglomerative Clustering with PCA and k=4: 0.5040470882967498

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import OPTICS
from sklearn.metrics import silhouette_score

# Load the cleaned GeoJSON data
gdf = gpd.read_file(r"/Users/chenyutong/Downloads/updated_geojson.geojson")

# Step 1: Standardizing the Data
independent_vars = ['HDX_2018-2022', 'INC_2018-2022', 'HTJ_2018-2022',
                    'NCZ_2018-2022', 'LEQ_2018-2022', 'EDB_2018-2022',
                    'EDE_2018-2022', 'UNS_2018-2022', 'MCD_2018-2022']

data = gdf[independent_vars]
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Step 2: Apply PCA for Dimensionality Reduction
pca = PCA(n_components=2)
data_pca = pca.fit_transform(data_scaled)

# Step 3: OPTICS Clustering
optics = OPTICS(min_samples=5, xi=0.05, min_cluster_size=0.1)
optics_labels = optics.fit_predict(data_pca)
gdf['OPTICS_Cluster'] = optics_labels

# Step 4: Calculate Silhouette Score for OPTICS
# Filtering out noise points (-1 labels)
valid_labels = optics_labels[optics_labels != -1]
if len(set(valid_labels)) > 1:
    optics_silhouette = silhouette_score(data_pca[optics_labels != -1], valid_labels)
    print(f"Silhouette Score for OPTICS: {optics_silhouette}")
else:
    optics_silhouette = "Not enough clusters to calculate silhouette score"
    print(optics_silhouette)

# Step 5: Visualization of OPTICS Clustering with Gradient Brown Color
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
base = gdf.plot(ax=ax, color='lightgrey', edgecolor='black')
gdf[gdf['OPTICS_Cluster'] != -1].plot(column='OPTICS_Cluster', ax=base, cmap='copper', legend=True, alpha=0.8)
plt.title('OPTICS Clustering of Chicago Communities (Gradient Brown)')
plt.axis('off')
plt.savefig('optics_clustering_brown.png')
plt.show()
# Out:
# Silhouette Score for OPTICS: 0.7500071235976848

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned GeoJSON data
gdf = gpd.read_file(r"/Users/chenyutong/Downloads/updated_geojson.geojson")

# Define dependent variables and independent variables
dependent_var_1 = 'VRDIDR_2018-2022'  # Drug-induced mortality rate
dependent_var_2 = 'CZD_2018-2022'      # Drug abuse crimes (classification)
independent_vars = ['HDX_2018-2022', 'INC_2018-2022', 'HTJ_2018-2022',
                    'NCZ_2018-2022', 'LEQ_2018-2022', 'EDB_2018-2022',
                    'EDE_2018-2022', 'UNS_2018-2022', 'MCD_2018-2022']

# Rename columns for easier understanding and readability
readable_vars = {
    'HDX_2018-2022': 'Hardship Index',
    'INC_2018-2022': 'Median Income',
    'HTJ_2018-2022': 'Crowded Housing',
    'NCZ_2018-2022': 'Non-Citizens',
    'LEQ_2018-2022': 'Limited English',
    'EDB_2018-2022': 'High School Graduation',
    'EDE_2018-2022': 'College Graduation',
    'UNS_2018-2022': 'Uninsured Rate',
    'MCD_2018-2022': 'Medicaid Coverage'
}

data = gdf[independent_vars + [dependent_var_1, dependent_var_2]].dropna()
X = data[independent_vars]
X.rename(columns=readable_vars, inplace=True)

# Step 1: Feature Importance for Drug-Induced Mortality Rate (Random Forest Regressor)
y_vrdidr = data[dependent_var_1]
rf_reg = RandomForestRegressor(n_estimators=100, random_state=42)
rf_reg.fit(X, y_vrdidr)

# Get feature importance for mortality rate
feature_importances_vrdidr = rf_reg.feature_importances_
importance_df_vrdidr = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances_vrdidr})
importance_df_vrdidr = importance_df_vrdidr.sort_values(by='Importance', ascending=False)

# Plot feature importance for mortality rate
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=importance_df_vrdidr, color='b')
plt.title('Feature Importance in Predicting Drug-Induced Mortality Rate')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.savefig('feature_importance_vrdidr.png')
plt.show()

# Step 2: Feature Importance for Drug Abuse Crimes (Random Forest Classifier)
y_czd = data[dependent_var_2].apply(lambda x: 1 if x > data[dependent_var_2].median() else 0)
rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)
rf_clf.fit(X, y_czd)

# Get feature importance for drug abuse crimes
feature_importances_czd = rf_clf.feature_importances_
importance_df_czd = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances_czd})
importance_df_czd = importance_df_czd.sort_values(by='Importance', ascending=False)

# Plot feature importance for drug abuse crimes
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=importance_df_czd, color='r')
plt.title('Feature Importance in Predicting Drug Abuse Crimes')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.savefig('feature_importance_czd.png')
plt.show()

# Step 3: Combined Analysis
importance_df_vrdidr['Type'] = 'Mortality Rate'
importance_df_czd['Type'] = 'Drug Crimes'
combined_df = pd.concat([importance_df_vrdidr, importance_df_czd])

# Plot combined feature importance (Vertical Bar Chart)
plt.figure(figsize=(12, 8))
sns.barplot(x='Feature', y='Importance', hue='Type', data=combined_df, palette=['blue', 'red'])
plt.title('Comparison of Feature Importance for Mortality Rate and Drug Abuse Crimes')
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('combined_feature_importance.png')
plt.show()

# Step 4: Tabulate the Results in a Readable Format
# Create tables for feature importance
vrdidr_table = importance_df_vrdidr[['Feature', 'Importance']].copy()
czd_table = importance_df_czd[['Feature', 'Importance']].copy()

# Save tables as images or display them in a readable format
print("\nFeature Importance for Drug-Induced Mortality Rate:\n")
print(vrdidr_table.to_string(index=False))

print("\nFeature Importance for Drug Abuse Crimes:\n")
print(czd_table.to_string(index=False))
# Out:
# /var/folders/0f/x5ld7bsd51bf2l_h0h0sl0hw0000gn/T/ipykernel_87193/2140224071.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.rename(columns=readable_vars, inplace=True)
# Feature Importance for Drug-Induced Mortality Rate:
#
#                Feature  Importance
#      Medicaid Coverage    0.594294
#          Median Income    0.129379
# High School Graduation    0.105641
#        Limited English    0.038082
#         Hardship Index    0.031497
#        Crowded Housing    0.030268
#           Non-Citizens    0.028631
#         Uninsured Rate    0.023128
#     College Graduation    0.019080
#
# Feature Importance for Drug Abuse Crimes:
#
#                Feature  Importance
#      Medicaid Coverage    0.152017
#          Median Income    0.146532
#        Crowded Housing    0.129446
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
import geopandas as gpd
import pandas as pd

# Load the cleaned GeoJSON data
gdf = gpd.read_file(r"F:\Cleaned_Merged_Geodata.geojson")

# Step 1: Standardizing the Data
independent_vars = ['HDX_2018-2022', 'INC_2018-2022', 'HTJ_2018-2022', 
                    'NCZ_2018-2022', 'LEQ_2018-2022', 'EDB_2018-2022', 
                    'EDE_2018-2022', 'UNS_2018-2022', 'MCD_2018-2022']
data = gdf[independent_vars]
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Step 2: PCA for Dimensionality Reduction
pca = PCA(n_components=2)
data_pca = pca.fit_transform(data_scaled)

# Step 3: DBSCAN Clustering
# Define eps and min_samples values based on previous testing or trial-and-error
dbscan = DBSCAN(eps=0.5, min_samples=5)  # Adjust eps value accordingly
dbscan_labels = dbscan.fit_predict(data_pca)

# Add DBSCAN labels to the GeoDataFrame
gdf['DBSCAN_Cluster_PCA'] = dbscan_labels

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics.pairwise import cosine_similarity

# Define the resilient communities (resilient)
resilient = gdf[
    (gdf['HDX_2018-2022'] > gdf['HDX_2018-2022'].median()) &
    (gdf['VRDIDR_2018-2022'] < gdf['VRDIDR_2018-2022'].median()) &
    (gdf['EDE_2018-2022'] < gdf['EDE_2018-2022'].median())
]
resilient = resilient.sort_values(by=['HDX_2018-2022'], ascending=False).head(7)

# Define the culturally protected communities (cultural_protection)
cultural_protection = gdf[
    (gdf['NCZ_2018-2022'] > gdf['NCZ_2018-2022'].median()) &
    (gdf['LEQ_2018-2022'] > gdf['LEQ_2018-2022'].median())
]
cultural_protection = cultural_protection.sort_values(by=['NCZ_2018-2022'], ascending=False).head(7)

# Create a combined dataset for Resilient + Cultural Protection Communities
combined_resilient_cultural = pd.concat([resilient, cultural_protection]).drop_duplicates()

# Step 1: Create binary columns for the DBSCAN Yellow Cluster and Combined Communities
# Assuming that the yellow cluster label in DBSCAN clustering is denoted as '1'
yellow_cluster = (gdf['DBSCAN_Cluster_PCA'] == 1).astype(int)

# Create a binary column for the Combined Resilient + Cultural Communities
combined_resilient_cultural_idx = combined_resilient_cultural.index
gdf['Combined_Resilient_Cultural'] = gdf.index.isin(combined_resilient_cultural_idx).astype(int)

# Step 2: Calculate Jaccard Similarity
jaccard_similarity = jaccard_score(yellow_cluster, gdf['Combined_Resilient_Cultural'])
print(f"Jaccard Similarity between Combined Communities and Yellow Cluster: {jaccard_similarity:.2f}")

# Step 3: Calculate Cosine Similarity for Feature Profiles
features = ['HDX_2018-2022', 'INC_2018-2022', 'LEQ_2018-2022', 'HTJ_2018-2022', 'EDB_2018-2022']

# Extract feature means for Yellow Cluster and Combined Communities
yellow_features = gdf[yellow_cluster == 1][features].mean().values.reshape(1, -1)
combined_features = gdf[gdf['Combined_Resilient_Cultural'] == 1][features].mean().values.reshape(1, -1)

# Calculate Cosine Similarity
cosine_sim = cosine_similarity(yellow_features, combined_features)[0][0]
print(f"Cosine Similarity between Yellow Cluster and Combined Communities Feature Profiles: {cosine_sim:.2f}")
# Out:
# Jaccard Similarity between Combined Communities and Yellow Cluster: 0.00
# Cosine Similarity between Yellow Cluster and Combined Communities Feature Profiles: 1.00
